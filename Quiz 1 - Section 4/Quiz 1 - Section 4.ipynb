# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 1 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your own code

name = "John Jaquez"
print(name)
# Out:
# John Jaquez

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
## Write your own code

print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pytplot", and "pandas"

# %%
# Write your own code

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## <span style="color:darkblue"> Part I: Visualizing random variables </span>

# %% [markdown]
# <font size = "5">
#
# (a) Create two random variables ...
#
#
# - Call them "vec_x" and "vec_z"
# - Generate "vec_x" from a chi-square with (df = 5, size = 1000)
# - Generate "vec_z" from a chi-square distribution with (df = 1, size = 1000)
# - Plot a histogram of each variable
#     - Label the axes and title
#     - Each graph should have a different title
#
# To get full points, plot the histograms on a grid (See Lecture 6)

# %%
# Write your own code

vec_x = [np.random.chisquare(df = 5, size = 1000)]
vec_z = [np.random.chisquare(df = 1, size = 1000)]

fig, list_subsquare = plt.subplots(1, 2,figsize = (12,6))

plt.tight_layout()

list_subsquare[0].hist(x = vec_x)
list_subsquare[0].set_title("Figure 1: Chi-Square Distribution of Vec X")
list_subsquare[0].set_xlabel("Value")
list_subsquare[0].set_ylabel("Frequency")

list_subsquare[1].hist(x = vec_z)
list_subsquare[1].set_title("Figure 2: Chi-Square Distribution of Vec Z")
list_subsquare[1].set_xlabel("Value")
list_subsquare[1].set_ylabel("Frequency")
# Out:
# Text(619.8699494949494, 0.5, 'Frequency')

# %% [markdown]
# <font size = "5">
#
# (b) Create a new variable "vec_y" by the formula
#
# $ y = sin(x) + 2x + 5$
#
# - Use element-by-element vector operations (no loops)
# - Produce a scatter plot of "vec_y" against "vec_x"
# - Label the axes and the title
# - Change the color to "red", "green" or "purple" (you choose)
#
# Hint: You can use the numpy "sin()" function with vector arrays

# %%
# Write your own code

x = vec_x

vec_y = np.sin(x) + 2*x +5

plt.scatter(x = vec_x, y = vec_y, color = "red")
plt.title("Relation ship between Vec_X and Vec_Y")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/mh/ydcx9nwx56qc26djm825tjf40000gn/T/ipykernel_97211/2924690962.py in <module>
#       5 vec_y = np.sin(x) + 2*x +5
#       6
# ----> 7 plt.scatter(x = vec_x, y = vec_y, color = "red")
#       8 plt.title("Relation ship between Vec_X and Vec_Y")
#       9 plt.xlabel("Values")
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2817         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2818         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2819     __ret = gca().scatter(
#    2820         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2821         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4360         y = np.ma.ravel(y)
#    4361         if x.size != y.size:
# -> 4362             raise ValueError("x and y must be the same size")
#    4363
#    4364         if s is None:
#
# ValueError: x and y must be the same size

# %% [markdown]
# ## <span style="color:darkblue"> Part II: Operations over multiple datasets </span>

# %% [markdown]
# <font size = "5">
#
# (c) Create two lists with ...
#
# - The names of the datasets
# - The years of the datasets (type manually based on the dataset names)
#
# To answer this question, you need to browse the Quiz folder
#
# You will find three datasets on worldwide CO2 emissions

# %%
# Write your own code

list_datasets = ["wdi_co2_2005", "wdi_co2_2010", "wdi_co2_2015"]
list_datasetyears = [2005, 2010, 2015]

# %% [markdown]
# <font size = "5">
#
# (d) Create a loop that ...
#
#
# - Goes over the list of years
# - If the year $\ge$ 2012, print the message
#
# $\qquad$ "This dataset contains information on or after 2012.
#
# - If the year $<$ 2012, print the message
#
# $\qquad$ "This dataset contains information before 2012"

# %%
# Write your own code

list_datasetyears = [2005, 2010, 2015]

for year in list_datasetyears:
    if year >= 2012:
        print("This dataset contains information on or after 2012")
    else:
        print("This dataset contains information before 2012")
# Out:
# This dataset contains information before 2012
# This dataset contains information before 2012
# This dataset contains information on or after 2012

# %% [markdown]
# <font size = "5">
#
# (e) Your goal is to convert all the ".csv" data files to ".xlsx" (Excel) files
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Create a new list called "list_newnames", with each element ending in ".xlsx" (including the subfolder "data_excel/")
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the ".csv" dataset and store it in an object called "dataset"
#     - Create a variable called "filename" from the "list_newnames", extracting the element "index"
#     - Store "dataset" as an excel file with name "filename".
#
#     $\qquad$ index = index + 1
#
# Note: Check that you did it correctly by trying to open your new excel files outside "VSCode"

# %%
# Write your own code

list_datasetnames = ["data_quiz/wdi_co2_2005.csv", "data_quiz/wdi_co2_2010.csv","data_quiz/wdi_co2_2015.csv"]
list_newnames = ["data_quiz/wdi_co2_2005.xlsx", "data_quiz/wdi_co2_2005.xlsx", "data_quiz/wdi_co2_2005.xlsx"]

index = 0 
for datasetnames in list_datasetnames:
    pd.read_csv("")

# %% [markdown]
# <font size = "5">
#
# (f) Your goal is to open each dataset, create a new variable, then plot
#
#
# <font size = "3">
#
# - Create a list with the ".csv" dataset names (including their relative subfolder "data_quiz/)
# - Start an index
#
# $\qquad$ index = 0
#
# - Initiate a for loop over the list of dataset names. Inside the loop:
#     - Read the dataset and store it in an object called "dataset"
#     - Create two new variables as
#
#     $\qquad$ co2_gasfuel_kt = dataset["co2_gasfuel_kt"] <br>
#     $\qquad$ co2_liquidfuel_kt = dataset["co2_liquidfuel_kt"]
#
#     - Calculate the total CO2 emissions driven by gas and liquid fuel by adding the two previous variables.
#     - Plot a histogram and label the axes
#     - Use plt.show() to display the plot
#     - Write
#
#     $\qquad$ index = index + 1
#
#
# This should produce a histogram for each dataset

# %%
# Write your own code
